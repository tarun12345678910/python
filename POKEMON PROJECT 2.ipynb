# %%
import pandas as pd

# %%
df=pd.read_csv('pokemon (1).csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# To read a specific name from the data

# %%
df.iloc[0,1]
# Out:
# 'Bulbasaur'

# %%
# To see the counts of the category in data

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
# To find a specific imformation in a data or to apply a condition

# %%
df[df['Type 1']=='Water']
# Out:
#        #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9      7                 Squirtle  Water    NaN  44      48       65       50
# 10     8                Wartortle  Water    NaN  59      63       80       65
# 11     9                Blastoise  Water    NaN  79      83      100       85
# 12     9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59    54                  Psyduck  Water    NaN  50      52       48       65
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 724  656                  Froakie  Water    NaN  41      56       40       62
# 725  657                Frogadier  Water    NaN  54      63       52       83
# 726  658                 Greninja  Water   Dark  72      95       67      103
# 762  692                Clauncher  Water    NaN  50      53       62       58
# 763  693                Clawitzer  Water    NaN  71      73       88      120
#
# ...

# %%
# To  sort the valuesof all columns by any one column

# %%
df.sort_values(['HP']) # BY DEFAULT IT CAN SORT IN ASCENDING ORDER
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 487  439   Mime Jr.  Psychic    NaN   20      25       45       70       90
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
# To sort the values in descending order

# %%
df.sort_values(['Attack'],ascending=False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground       NaN  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Find the values which are greater than 100 in attack column

# %%
df[df['Attack']>100]
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X     Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire  Flying   78     104       78
# 12     9    BlastoiseMega Blastoise    Water     NaN   79     103      120
# 19    15      BeedrillMega Beedrill      Bug  Poison   65     150       40
# 39    34                   Nidoking   Poison  Ground   81     102       77
# ..   ...                        ...      ...     ...  ...     ...      ...
# 793  717                    Yveltal     Dark  Flying  126     131       95
# 796  719        DiancieMega Diancie     Rock   Fairy   50     160      110
# 797  720        HoopaHoopa Confined  Psychic   Ghost   80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    Dark   80     160       60
# 799  721                  Volcanion     Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# To find unique values in any column

# %%
df['Type 1'].unique
# Out:
# <bound method Series.unique of 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object>

# %%
# To create new column (Total)

# %%
df['Total']=df.iloc[0:,2:8].sum(axis=1)
df
# Out:
# C:\Users\Tarun Bhardwaj\AppData\Local\Temp\ipykernel_5296\1191018498.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Total']=df.iloc[0:,2:8].sum(axis=1)
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# ...

# %%
# Find those pokemon from the data who are psychic and their attacing power is equal to 190

# %%
df[(df['Type 1']=='Psychic')&(df['Attack']==190)]
# Out:
#        #                 Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 163      154      100    130           1       True    550

# %%
# Find the strongest pokemon

# %%
df.groupby(['Name'])['Attack'].agg(['max']).sort_values(by='max',ascending=False)
# Out:
#                          max
# Name
# MewtwoMega Mewtwo X      190
# HeracrossMega Heracross  185
# GroudonPrimal Groudon    180
# DeoxysAttack Forme       180
# RayquazaMega Rayquaza    180
# ...                      ...
# Magikarp                  10
# Shuckle                   10
# Blissey                   10
# Chansey                    5
# Happiny                    5
#
# [800 rows x 1 columns]
