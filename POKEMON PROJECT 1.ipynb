# %%
import pandas as pd

# %%
# QUESTION:-How to read a file in pandas

# %%
df=pd.read_csv('pokemon (1).csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# To read 5 rows from starting

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# To read last 5 rows from dataset

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# To check how many rows and columns in dataset

# %%
df.shape
# Out:
# (800, 12)

# %%
# To see all the columns names of the data

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# To check the information of the columns

# %%
df.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# To see the status of the data

# %%
df.describe()  #BY DEFAULT IT GIVES NUMERIC DATA INFORMATION
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
 df.describe(include='object') # FOR NON NUMERIC DATA
# Out:
#              Name Type 1  Type 2
# count         800    800     359
# unique        800     18      18
# top     Bulbasaur  Water  Flying
# freq            1    112      81

# %%
# To see unique values in any column of the data

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# To count unique

# %%
df.nunique()
# Out:
# #             721
# Name          800
# Type 1         18
# Type 2         18
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %%
# To check the missing values in data

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        441
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.isnull().sum().sum() # To check the complete missing values
# Out:
# 441

# %%
# To check the missing values in data in percentage

# %%
df.isnull().sum()/df.shape[0]*(100)
# Out:
# #              0.000
# Name           0.000
# Type 1         0.000
# Type 2        55.125
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %%
# to drop any column from the data

# %%
df.drop(columns=['HP'],inplace=True)
df
# Out:
#                       Name   Type 1  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0                Bulbasaur    Grass      49       49       65       65     45
# 1                  Ivysaur    Grass      62       63       80       80     60
# 2                 Venusaur    Grass      82       83      100      100     80
# 3    VenusaurMega Venusaur    Grass     100      123      122      120     80
# 4               Charmander     Fire      52       43       60       50     65
# ..                     ...      ...     ...      ...      ...      ...    ...
# 795                Diancie     Rock     100      150      100      150     50
# 796    DiancieMega Diancie     Rock     160      110      160      110    110
# 797    HoopaHoopa Confined  Psychic     110       60      150      130     70
# 798     HoopaHoopa Unbound  Psychic     160       60      170      130     80
# 799              Volcanion     Fire     110      120      130       90     70
#
#      Generation  Legendary
# ...

# %%
# To read each column

# %%
df['Name']  # SIMILAR FOR ALL THE COLUMNS
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# To read multiple columns

# %%
df[['Name','Type 1']]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
# To read each row

# %%
df.iloc[9]
# Out:
# Name          Squirtle
# Type 1           Water
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %%
# To read multiple rows

# %%
df.iloc[9:12]
# Out:
#          Name Type 1  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 9    Squirtle  Water      48       65       50       64     43           1
# 10  Wartortle  Water      63       80       65       80     58           1
# 11  Blastoise  Water      83      100       85      105     78           1
#
#     Legendary
# 9       False
# 10      False
# 11      False
